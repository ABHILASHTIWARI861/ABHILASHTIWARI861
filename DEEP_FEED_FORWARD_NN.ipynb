# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHILASHTIWARI861/ABHILASHTIWARI861/blob/main/DEEP_FEED_FORWARD_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])
w1 = np.random.randn(2,2)
w2 = np.random.randn(2,1)
b1 = np.random.randn(1,2)
b2 = np.random.randn(1,1)

def sigmoid(z):
  return 1 / (1+np.exp(-z))
def sigmoid_derivative(x):
  return x * (1-x)

def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return np.where(x > 0, 1, 0)

def tanh(x):
    return np.tanh(x)

def tanh_derivative(x):
    return 1 - np.tanh(x)**2

lr = 0.01

for epoch in range(10000):

    hidden_input = np.dot(x, w1) + b1
    hidden_layer = relu(hidden_input)
    output_layer = sigmoid(np.dot(hidden_layer, w2) + b2)

    error = y - output_layer


    d_output = error * sigmoid_derivative(output_layer)
    d_hidden = d_output.dot(w2.T) * relu_derivative(hidden_input)

    w2 += hidden_layer.T.dot(d_output) * lr
    w1 += x.T.dot(d_hidden) * lr
    b2 += np.sum(d_output, axis=0, keepdims=True) * lr
    b1 += np.sum(d_hidden, axis=0, keepdims=True) * lr

print("Predicted Output (ReLU):")
print(output_layer)
# Out:
# Predicted Output (ReLU):
# [[0.11654311]
#  [0.80966177]
#  [0.92854074]
#  [0.07431479]]
